# %% [markdown]
# # Example notebook article

# %% [markdown]
# <!--PELICAN_BEGIN_SUMMARY-->
#
# Here is an equation...I'm not sure how long these sentences need to be to wrap properly.  I guess about a line.
#
# Here's the equation again: $e=mc^2$.
#
# <!-- PELICAN_END_SUMMARY -->

# %%
# %matplotlib inline
import numpy as np
import matplotlib.pylab as plt

x = np.linspace(0, 2*np.pi, 50)
y = np.sin(x)

plt.plot(x,y);
